# %%
# !pip install wfdb
# Out:
# Collecting wfdb
#   Downloading https://files.pythonhosted.org/packages/f1/99/4b4749925cf4123643b512e27710bfaad4f048eba8b840c581780e2aada9/wfdb-3.2.0-py3-none-any.whl (119kB)
#      |████████████████████████████████| 122kB 5.9MB/s
# Requirement already satisfied: python-dateutil>=2.4.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.8.1)
# Requirement already satisfied: chardet>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (3.0.4)
# Requirement already satisfied: requests>=2.8.1 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.23.0)
# Requirement already satisfied: certifi>=2016.8.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2020.12.5)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (0.10.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.0.0)
# Requirement already satisfied: pandas>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.1.5)
# Collecting threadpoolctl>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2018.9)
# Requirement already satisfied: pyparsing>=2.0.4 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.4.7)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (3.2.2)
# Requirement already satisfied: idna>=2.2 in /usr/local/lib/python3.6/dist-packages (from wfdb) (2.10)
# Requirement already satisfied: numpy>=1.10.1 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.6/dist-packages (from wfdb) (0.22.2.post1)
# Requirement already satisfied: urllib3>=1.22 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.24.3)
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from wfdb) (1.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4.2->wfdb) (1.15.0)
# Installing collected packages: threadpoolctl, wfdb
# Successfully installed threadpoolctl-2.1.0 wfdb-3.2.0

# %% [markdown]
# ## Download data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#!wget -r -N -c -np https://physionet.org/files/ptbdb/1.0.0/ /content/gdrive/

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/
# Out:
# /content/gdrive

# %%
import os

# %%
data_path='/content/gdrive/My Drive/physionet.org/files/ptbdb/1.0.0'

# %%
import numpy as np

# %% [markdown]
# ## discover the data

# %%
import wfdb
import numpy as np
import matplotlib.pyplot as plt
# plot ECG
def draw_ecg(x):
    plt.plot(x)
    plt.show()

#  read_ecg_data
def read_ecg_data(file_path,channel_names,sampfrom=0,smpto=1500):
    '''
    to read the ECG data
    sampfrom: start point，default sampfrom=0
    sampto：end poit，default to the end of data
    channel_names： chanel names which is a list，eg. channel_names=['vx']
    channels：a list with numbers，eg. channels=[0, 3]
    :return: record of ECG
    '''      
    record = wfdb.rdrecord(file_path, sampfrom=0, sampto = 1500 ,channel_names=['vz'])
    print(type(record))

    print(dir(record))
    
    print(record.p_signal)
    print(np.shape(record.p_signal))
    print(record.sig_len)
  
    print(record.record_name)
   
    print(record.n_sig)
   
    print(record.sig_name)
   
    print(record.fs)


    print("***************")
      

    
    print(wfdb.show_ann_labels())

    draw_ecg(record.p_signal)
    return record


#test function
test_file=data_path+'/patient001/s0014lre'
read_ecg_data(test_file,'vx')
# Out:
# <class 'wfdb.io.record.Record'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_adjust_datetime', '_arrange_fields', 'adc', 'adc_gain', 'adc_res', 'adc_zero', 'base_counter', 'base_date', 'base_time', 'baseline', 'block_size', 'byte_offset', 'calc_adc_params', 'calc_checksum', 'check_field', 'check_field_cohesion', 'check_read_inputs', 'check_sig_cohesion', 'checksum', 'comments', 'convert_dtype', 'counter_freq', 'd_signal', 'dac', 'e_d_signal', 'e_p_signal', 'file_name', 'fmt', 'fs', 'get_write_fields', 'get_write_subset', 'init_value', 'n_sig', 'p_signal', 'record_name', 'samps_per_frame', 'set_d_features', 'set_default', 'set_defaults', 'set_p_features', 'sig_len', 'sig_name', 'skew', 'smooth_frames', 'units', 'wr_dat_files', 'wr_dats', 'wr_header_file', 'wrheader', 'wrsamp']
# [[0.9675]
#  [0.9645]
#  [0.961 ]
#  ...
#  [0.945 ]
#  [0.946 ]
#  [0.9465]]
# (1500, 1)
# 1500
# s0014lre
# 1
# ['vz']
# 1000
# ***************
#     label_store symbol                                    description
# 0             0                              Not an actual annotation
# 1             1      N                                    Normal beat
# 2             2      L                  Left bundle branch block beat
# 3             3      R                 Right bundle branch block beat
# 4             4      a                Aberrated atrial premature beat
# 5             5      V              Premature ventricular contraction
# 6             6      F          Fusion of ventricular and normal beat
# 7             7      J              Nodal (junctional) premature beat
# 8             8      A                   Atrial premature contraction
# 9             9      S     Premature or ectopic supraventricular beat
# 10           10      E                        Ventricular escape beat
# 11           11      j                 Nodal (junctional) escape beat
# 12           12      /                                     Paced beat
# 13           13      Q                            Unclassifiable beat
# 14           14      ~                          Signal quality change
# 16           16      |                     Isolated QRS-like artifact
# 18           18      s                                      ST change
# 19           19      T                                  T-wave change
# 20           20      *                                        Systole
# 21           21      D                                       Diastole
# 22           22      "                             Comment annotation
# 23           23      =                         Measurement annotation
# 24           24      p                                    P-wave peak
# 25           25      B              Left or right bundle branch block
# 26           26      ^                      Non-conducted pacer spike
# 27           27      t                                    T-wave peak
# 28           28      +                                  Rhythm change
# 29           29      u                                    U-wave peak
# 30           30      ?                                       Learning
# 31           31      !                       Ventricular flutter wave
# 32           32      [      Start of ventricular flutter/fibrillation
# 33           33      ]        End of ventricular flutter/fibrillation
# 34           34      e                             Atrial escape beat
# 35           35      n                   Supraventricular escape beat
# 36           36      @  Link to external data (aux_note contains URL)
# 37           37      x             Non-conducted P-wave (blocked APB)
# 38           38      f                Fusion of paced and normal beat
# 39           39      (                                 Waveform onset
# 40           40      )                                   Waveform end
# 41           41      r       R-on-T premature ventricular contraction
# None

# %% [markdown]
# # read all data to pd dataframe

# %%
import os
import wfdb
import pandas as pd
import pywt
def denoise(data):
    # wavedec
    coeffs = pywt.wavedec(data=data, wavelet='db8', level=9)
    cA9, cD9, cD8, cD7, cD6, cD5, cD4, cD3, cD2, cD1 = coeffs

    # threshold
    threshold = (np.median(np.abs(cD1)) / 0.6745) * (np.sqrt(2 * np.log(len(cD1))))
    cD1.fill(0)
    cD2.fill(0)
    for i in range(1, len(coeffs) - 2):
        coeffs[i] = pywt.threshold(coeffs[i], threshold)

    rdata = pywt.waverec(coeffs=coeffs, wavelet='db8')
    return rdata
data_path='/content/gdrive/My Drive/physionet.org/files/ptbdb/1.0.0'

def read_data_files(data_path, label_1, sampfrom, sampto):
  
  path_names=os.listdir(data_path)
 # for name in path_names:
  #  if not os.path.isdir(name):
#      path_names.remove(name) 
  i=0
  records = []      
  labels = []           
  for patient_path in path_names:
      PATH=os.path.join(data_path,patient_path)   #path
      #if not os.path.isfile(PATH):
      FILES=os.listdir(PATH)
         #print(FILES) 
        # data_files=[]             
      for file in FILES:
        if '.hea' in file:
              #print(file)
              # data_files.append(file)
            
          record_path=os.path.join(PATH,file.split('.')[0])
          record= wfdb.rdrecord(record_path, sampfrom=sampfrom, sampto = sampto)
          label = record.comments[4].split(':')[1]

          if  label == label_1:
            label = 1
          else:
            label = 0
          #print(label,file)  
          sig_data = record.p_signal.T
          for single_sig in sig_data:
            sigle_sig = denoise(single_sig)
          records.append(sig_data)
          labels.append(label)
  df = pd.DataFrame(columns=['data','label'])
  df['data'] = records
  df['label'] = labels
  return df         

sampfrom=0
sampto = 30000
#all_records=read_data_files(data_path)
df = read_data_files(data_path,' Myocardial infarction',sampfrom, sampto)

# %%
df.shape
# Out:
# (549, 2)

# %%
df.head()
# Out:
#                                                 data  label
# 0  [[-0.2445, -0.2425, -0.2415, -0.241, -0.2315, ...      1
# 1  [[-0.474, -0.444, -0.4555, -0.462, -0.459, -0....      1
# 2  [[0.254, 0.263, 0.2755, 0.28, 0.3035, 0.305, 0...      1
# 3  [[0.2735, 0.287, 0.2925, 0.312, 0.3275, 0.3305...      1
# 4  [[-0.6195, -0.6225, -0.626, -0.6275, -0.626, -...      1

# %%
df['label'].value_counts().plot(kind='bar')

# %%
type(df.data[0])
# Out:
# numpy.ndarray

# %% [markdown]
# ## resampling function

# %%
from sklearn.utils import resample
#up sampling the miniority class of dataset
df_majority = df[df.label==1]
df_minority = df[df.label==0]
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples= 368,    # to match majority class
                                 random_state=123) # reproducible results
df_new = pd.concat([df_majority, df_minority_upsampled], ignore_index= True)
df_new.label.value_counts()
# Out:
# 1    368
# 0    368
# Name: label, dtype: int64

# %%
print(df.data[0].shape)
# Out:
# (15, 30000)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from io import StringIO
import json
from keras.utils import to_categorical
import tensorflow as tf
from sklearn.model_selection import train_test_split

#Model function
from keras.models import Sequential
from keras.layers import BatchNormalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.constraints import max_norm
from sklearn.model_selection import train_test_split
import pywt
import datetime

from wfdb import io, plot
import wfdb
import os
import gc
from tqdm import tqdm_notebook as tqdm
#%matplotlib notebook
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, Input
from keras.layers import LSTM
from keras.callbacks import ModelCheckpoint
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
import time
import keras
from keras.optimizers import RMSprop, Adam
import pywt
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **CNN**

# %%
X = np.array(df_new['data'].tolist())
X.shape
# Out:
# (736, 15, 30000)

# %%
y = to_categorical(df_new['label'],2)

# %%
y.shape
# Out:
# (736, 2)

# %%
#split the train, test data from x,y
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)#try stratify
#split the valid data from train data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=1) # 0.25 x 0.8 = 0.2

# %%
X_train.shape
# Out:
# (441, 15, 30000)

# %%
X_val.shape
# Out:
# (147, 15, 30000)

# %%
X_test.shape
# Out:
# (148, 15, 30000)

# %%
class TimeHistory(tf.keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
# def make_whole_set(df_data, channels, label_map, record_id,window_size):
#     n_windows = df_data.shape[0]
    
#     min_length = df_data['signal_length'].min()

#     if window_size is None:
#       window_size = min_length

#     dataX = np.zeros((n_windows, len(channels), window_size))
#     dataY = np.zeros((n_windows, len(label_map)))
    
#     record_list = []
    
#     nth_window = 0
#     for i, (patient, record) in enumerate(tqdm(df_data.iterrows())):
#         # read the record, get the signal data and transpose it
#         signal_data = io.rdrecord(os.path.join(data_path, record['name'])).p_signal[0:window_size].transpose()
       
#         dataX[i] = np.array(signal_data)
#         dataY[i][label_map[record.label]] = 1
        
        
#         if record_id:
#             record_list = [record['name']]
        
#     return dataX, dataY, record_list,window_size

# %%
# trainX, trainY, _,window_size = make_whole_set(df_train_patients, channels, label_map, False, None)

# testX, testY, record_list,_ = make_whole_set(df_test_patients, channels, label_map, True, window_size)
# # window_size = 1024
# # trainX, trainY, _ = make_set(df_train_patients, channels, label_map, False, window_size)
# # testX, testY, record_list = make_set(df_test_patients, channels, label_map, True,window_size)

# #split validation set
# testX, valX, testY, valY = train_test_split(testX, testY, test_size=0.25, random_state=1)

#Shuffle order of train set
trainX, trainY = shuffle(X_train, y_train)

#Since we have a large class inbalance we need to udjust the weights for it.
fractions = 1-trainY.sum(axis=0)/len(trainY)
weights = fractions[trainY.argmax(axis=1)]

# %%
trainX.shape
# Out:
# (441, 15, 30000)

# %%
#shape:(100, 15, 32000)
def buildModel_CNN():

    newModel = tf.keras.models.Sequential([
                                           
        tf.keras.layers.InputLayer(input_shape=(15,30000)),

        tf.keras.layers.Conv1D(filters=4, kernel_size=21, strides=1, padding='SAME', activation='relu'),
       
        tf.keras.layers.AvgPool1D(pool_size=1, strides=4, padding='SAME'),
        
        tf.keras.layers.Conv1D(filters=16, kernel_size=23, strides=1, padding='SAME', activation='relu'),
        
        tf.keras.layers.AvgPool1D(pool_size=1, strides=4, padding='SAME'),
       
        tf.keras.layers.Conv1D(filters=32, kernel_size=25, strides=1, padding='SAME', activation='elu'),
       
        tf.keras.layers.AvgPool1D(pool_size=1, strides=8, padding='SAME'),
       
        tf.keras.layers.Conv1D(filters=64, kernel_size=27, strides=1, padding='SAME', activation='relu'),
       
        tf.keras.layers.Flatten(),
       
        tf.keras.layers.Dense(128, activation='relu'),
       
        tf.keras.layers.Dropout(rate=0.2),
       
        tf.keras.layers.Dense(2, activation='softmax')
    ])

    return newModel

# %%
model_test_CNN2 = buildModel_CNN()

# %%
model_test_CNN2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 15, 4)             2520004
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 4, 4)              0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 4, 16)             1488
# _________________________________________________________________
# average_pooling1d_1 (Average (None, 1, 16)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1, 32)             12832
# _________________________________________________________________
# average_pooling1d_2 (Average (None, 1, 32)             0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1, 64)             55360
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8320
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 2,598,262
# Trainable params: 2,598,262
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_val.shape
# Out:
# (147, 15, 30000)

# %%
import datetime
import tensorboard
# %load_ext tensorboard
model_test_CNN2.compile(optimizer = 'adam', 
                  loss = "binary_crossentropy", metrics=["accuracy"])

log_dir = "logs/fit_CNN2/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

model_test_CNN2.fit(trainX, trainY, validation_data=(X_val, y_val),validation_batch_size = 4, epochs=250,
                    batch_size=4 )
# Out:
# Epoch 1/250
# 111/111 [==============================] - 7s 23ms/step - loss: 0.7052 - accuracy: 0.5126 - val_loss: 0.6826 - val_accuracy: 0.6054
# Epoch 2/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.6560 - accuracy: 0.6156 - val_loss: 0.6553 - val_accuracy: 0.6327
# Epoch 3/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.6375 - accuracy: 0.6258 - val_loss: 0.6928 - val_accuracy: 0.6463
# Epoch 4/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.6284 - accuracy: 0.6623 - val_loss: 0.5922 - val_accuracy: 0.7007
# Epoch 5/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.5213 - accuracy: 0.7514 - val_loss: 0.6218 - val_accuracy: 0.6531
# Epoch 6/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.5185 - accuracy: 0.7618 - val_loss: 0.7918 - val_accuracy: 0.6395
# Epoch 7/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.4884 - accuracy: 0.7842 - val_loss: 0.6312 - val_accuracy: 0.7279
# Epoch 8/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.4104 - accuracy: 0.8116 - val_loss: 0.6808 - val_accuracy: 0.6531
# Epoch 9/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3229 - accuracy: 0.8976 - val_loss: 0.6340 - val_accuracy: 0.6054
# Epoch 10/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.4694 - accuracy: 0.7442 - val_loss: 0.6216 - val_accuracy: 0.6735
# Epoch 11/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3789 - accuracy: 0.8258 - val_loss: 0.7102 - val_accuracy: 0.5986
# Epoch 12/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.4270 - accuracy: 0.8009 - val_loss: 0.8900 - val_accuracy: 0.6667
# Epoch 13/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2951 - accuracy: 0.8804 - val_loss: 0.8280 - val_accuracy: 0.6190
# Epoch 14/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.4179 - accuracy: 0.8637 - val_loss: 0.8054 - val_accuracy: 0.6735
# Epoch 15/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2479 - accuracy: 0.8864 - val_loss: 0.8222 - val_accuracy: 0.6803
# Epoch 16/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2465 - accuracy: 0.8857 - val_loss: 0.8551 - val_accuracy: 0.6327
# Epoch 17/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2917 - accuracy: 0.8707 - val_loss: 0.8722 - val_accuracy: 0.6803
# Epoch 18/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2428 - accuracy: 0.8963 - val_loss: 1.0365 - val_accuracy: 0.6395
# Epoch 19/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3892 - accuracy: 0.8534 - val_loss: 0.8366 - val_accuracy: 0.6803
# Epoch 20/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2073 - accuracy: 0.9085 - val_loss: 0.9139 - val_accuracy: 0.6871
# Epoch 21/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2112 - accuracy: 0.8894 - val_loss: 1.1983 - val_accuracy: 0.7007
# Epoch 22/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2115 - accuracy: 0.9075 - val_loss: 0.9398 - val_accuracy: 0.6531
# Epoch 23/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3652 - accuracy: 0.8599 - val_loss: 0.6146 - val_accuracy: 0.7075
# Epoch 24/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2774 - accuracy: 0.8944 - val_loss: 0.8557 - val_accuracy: 0.7075
# Epoch 25/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1913 - accuracy: 0.9178 - val_loss: 1.1197 - val_accuracy: 0.6327
# Epoch 26/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2397 - accuracy: 0.9413 - val_loss: 1.0415 - val_accuracy: 0.6803
# Epoch 27/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1704 - accuracy: 0.9093 - val_loss: 1.2508 - val_accuracy: 0.7075
# Epoch 28/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0996 - accuracy: 0.9588 - val_loss: 1.6217 - val_accuracy: 0.6531
# Epoch 29/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3386 - accuracy: 0.8556 - val_loss: 1.0537 - val_accuracy: 0.6735
# Epoch 30/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1740 - accuracy: 0.9249 - val_loss: 1.5264 - val_accuracy: 0.7143
# Epoch 31/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1477 - accuracy: 0.9633 - val_loss: 1.7444 - val_accuracy: 0.6871
# Epoch 32/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2208 - accuracy: 0.9313 - val_loss: 1.4505 - val_accuracy: 0.6939
# Epoch 33/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2223 - accuracy: 0.8908 - val_loss: 1.4597 - val_accuracy: 0.7211
# Epoch 34/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1743 - accuracy: 0.9321 - val_loss: 1.3712 - val_accuracy: 0.6939
# Epoch 35/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1739 - accuracy: 0.9341 - val_loss: 0.8175 - val_accuracy: 0.7551
# Epoch 36/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0979 - accuracy: 0.9525 - val_loss: 1.2635 - val_accuracy: 0.7347
# Epoch 37/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1210 - accuracy: 0.9578 - val_loss: 1.2666 - val_accuracy: 0.7619
# Epoch 38/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3349 - accuracy: 0.9033 - val_loss: 1.0010 - val_accuracy: 0.7279
# Epoch 39/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0892 - accuracy: 0.9583 - val_loss: 1.3716 - val_accuracy: 0.6327
# Epoch 40/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3919 - accuracy: 0.8690 - val_loss: 0.7072 - val_accuracy: 0.7483
# Epoch 41/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.0986 - accuracy: 0.9631 - val_loss: 0.9165 - val_accuracy: 0.7143
# Epoch 42/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1162 - accuracy: 0.9761 - val_loss: 0.9227 - val_accuracy: 0.7483
# Epoch 43/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0762 - accuracy: 0.9649 - val_loss: 1.2362 - val_accuracy: 0.7347
# Epoch 44/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1169 - accuracy: 0.9561 - val_loss: 1.2830 - val_accuracy: 0.7075
# Epoch 45/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2461 - accuracy: 0.9213 - val_loss: 0.7086 - val_accuracy: 0.7755
# Epoch 46/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0513 - accuracy: 0.9874 - val_loss: 1.2820 - val_accuracy: 0.7687
# Epoch 47/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0581 - accuracy: 0.9829 - val_loss: 1.5072 - val_accuracy: 0.7279
# Epoch 48/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0696 - accuracy: 0.9759 - val_loss: 1.2456 - val_accuracy: 0.7483
# Epoch 49/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1314 - accuracy: 0.9584 - val_loss: 1.2332 - val_accuracy: 0.7143
# Epoch 50/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.0681 - accuracy: 0.9845 - val_loss: 1.3522 - val_accuracy: 0.7483
# Epoch 51/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0647 - accuracy: 0.9840 - val_loss: 1.6907 - val_accuracy: 0.7143
# Epoch 52/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.
# Epoch 141/250
# 111/111 [==============================] - 1s 12ms/step - loss: 2.5685e-06 - accuracy: 1.0000 - val_loss: 5.8907 - val_accuracy: 0.7755
# Epoch 142/250
# 111/111 [==============================] - 1s 12ms/step - loss: 4.9370e-07 - accuracy: 1.0000 - val_loss: 5.8990 - val_accuracy: 0.7755
# Epoch 143/250
# 111/111 [==============================] - 1s 12ms/step - loss: 2.7138e-05 - accuracy: 1.0000 - val_loss: 6.0642 - val_accuracy: 0.7823
# Epoch 144/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2055 - accuracy: 0.9641 - val_loss: 0.7531 - val_accuracy: 0.6327
# Epoch 145/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.5879 - accuracy: 0.7490 - val_loss: 0.6761 - val_accuracy: 0.6395
# Epoch 146/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3717 - accuracy: 0.8367 - val_loss: 0.7503 - val_accuracy: 0.6803
# Epoch 147/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3492 - accuracy: 0.8371 - val_loss: 0.7098 - val_accuracy: 0.6599
# Epoch 148/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.4252 - accuracy: 0.8426 - val_loss: 0.8240 - val_accuracy: 0.6395
# Epoch 149/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3911 - accuracy: 0.8518 - val_loss: 1.3060 - val_accuracy: 0.6803
# Epoch 150/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3116 - accuracy: 0.8984 - val_loss: 1.2818 - val_accuracy: 0.6939
# Epoch 151/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1299 - accuracy: 0.9411 - val_loss: 1.4558 - val_accuracy: 0.7075
# Epoch 152/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1105 - accuracy: 0.9631 - val_loss: 1.0868 - val_accuracy: 0.6939
# Epoch 153/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0737 - accuracy: 0.9719 - val_loss: 1.4741 - val_accuracy: 0.7007
# Epoch 154/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0727 - accuracy: 0.9684 - val_loss: 1.7470 - val_accuracy: 0.7211
# Epoch 155/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0424 - accuracy: 0.9820 - val_loss: 2.1924 - val_accuracy: 0.7347
# Epoch 156/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0399 - accuracy: 0.9781 - val_loss: 2.4956 - val_accuracy: 0.7279
# Epoch 157/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0270 - accuracy: 0.9900 - val_loss: 2.3543 - val_accuracy: 0.7075
# Epoch 158/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0575 - accuracy: 0.9653 - val_loss: 2.1045 - val_accuracy: 0.7279
# Epoch 159/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0362 - accuracy: 0.9867 - val_loss: 2.5179 - val_accuracy: 0.7143
# Epoch 160/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0158 - accuracy: 0.9940 - val_loss: 2.7293 - val_accuracy: 0.7211
# Epoch 161/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0151 - accuracy: 0.9969 - val_loss: 3.0256 - val_accuracy: 0.7211
# Epoch 162/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0357 - accuracy: 0.9865 - val_loss: 1.6314 - val_accuracy: 0.7075
# Epoch 163/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1285 - accuracy: 0.9547 - val_loss: 2.4038 - val_accuracy: 0.6735
# Epoch 164/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2620 - accuracy: 0.9205 - val_loss: 1.2674 - val_accuracy: 0.6803
# Epoch 165/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1313 - accuracy: 0.9499 - val_loss: 1.1788 - val_accuracy: 0.6735
# Epoch 166/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0630 - accuracy: 0.9876 - val_loss: 1.5527 - val_accuracy: 0.7143
# Epoch 167/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0442 - accuracy: 0.9753 - val_loss: 1.8988 - val_accuracy: 0.7279
# Epoch 168/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0943 - accuracy: 0.9631 - val_loss: 2.0470 - val_accuracy: 0.7143
# Epoch 169/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.
250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0499 - accuracy: 0.9830 - val_loss: 2.1107 - val_accuracy: 0.7143
# Epoch 227/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.0418 - accuracy: 0.9893 - val_loss: 2.9717 - val_accuracy: 0.7415
# Epoch 228/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0290 - accuracy: 0.9893 - val_loss: 3.4538 - val_accuracy: 0.7007
# Epoch 229/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1267 - accuracy: 0.9629 - val_loss: 1.9068 - val_accuracy: 0.7143
# Epoch 230/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0647 - accuracy: 0.9869 - val_loss: 2.3856 - val_accuracy: 0.7483
# Epoch 231/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0334 - accuracy: 0.9897 - val_loss: 2.9737 - val_accuracy: 0.7347
# Epoch 232/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0288 - accuracy: 0.9907 - val_loss: 3.4031 - val_accuracy: 0.7483
# Epoch 233/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.3427 - accuracy: 0.9693 - val_loss: 1.4139 - val_accuracy: 0.7687
# Epoch 234/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0890 - accuracy: 0.9792 - val_loss: 2.1336 - val_accuracy: 0.7619
# Epoch 235/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0501 - accuracy: 0.9807 - val_loss: 2.7679 - val_accuracy: 0.7551
# Epoch 236/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.0230 - accuracy: 0.9960 - val_loss: 2.7661 - val_accuracy: 0.7619
# Epoch 237/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0212 - accuracy: 0.9905 - val_loss: 2.9875 - val_accuracy: 0.7755
# Epoch 238/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 3.1077 - val_accuracy: 0.7687
# Epoch 239/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 3.2247 - val_accuracy: 0.7687
# Epoch 240/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0187 - accuracy: 0.9941 - val_loss: 3.4431 - val_accuracy: 0.7619
# Epoch 241/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 3.5859 - val_accuracy: 0.7755
# Epoch 242/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0057 - accuracy: 0.9989 - val_loss: 3.6559 - val_accuracy: 0.7551
# Epoch 243/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 3.9223 - val_accuracy: 0.7687
# Epoch 244/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0147 - accuracy: 0.9942 - val_loss: 3.6646 - val_accuracy: 0.7755
# Epoch 245/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 4.3324 - val_accuracy: 0.7483
# Epoch 246/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0151 - accuracy: 0.9974 - val_loss: 4.6551 - val_accuracy: 0.7619
# Epoch 247/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.1396 - accuracy: 0.9644 - val_loss: 1.7820 - val_accuracy: 0.7211
# Epoch 248/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.2441 - accuracy: 0.9107 - val_loss: 1.7370 - val_accuracy: 0.7347
# Epoch 249/250
# 111/111 [==============================] - 1s 13ms/step - loss: 0.1384 - accuracy: 0.9273 - val_loss: 2.4083 - val_accuracy: 0.7551
# Epoch 250/250
# 111/111 [==============================] - 1s 12ms/step - loss: 0.0871 - accuracy: 0.9667 - val_loss: 3.7019 - val_accuracy: 0.7347

# %%
output = model_test_CNN2.predict(X_test)
output_ = np.argmax(output,axis=1)
y_pred = output_
y_true = y_test.argmax(axis=1)
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83        73
#            1       0.85      0.81      0.83        75
#
#     accuracy                           0.83       148
#    macro avg       0.83      0.83      0.83       148
# weighted avg       0.83      0.83      0.83       148

# %% [markdown]
# # **LSTM**

# %%
def make_model_lstm(input_shape, output_dim, lstm_layer, dropout=0.2):
    print("model dim: ", input_shape, output_dim)
    model = Sequential()
    model.add(lstm_layer(256, return_sequences=True, input_shape=input_shape, batch_size=None))
    model.add(Dropout(dropout))
    model.add(lstm_layer(128, return_sequences=True))
    model.add(Dropout(dropout))
    model.add(LSTM(64))
    model.add(Dropout(dropout))
    model.add(Dense(output_dim, activation='softmax'))
    model.compile(loss='categorical_crossentropy',metrics=[tf.keras.metrics.BinaryAccuracy()] , optimizer='adam')
    
    return model

#shape:(3774, 15, 1024)

df_new.shape
# Out:
# (736, 2)

# %% [markdown]
# ## wave_slicing

# %%
import pandas as pd
import pywt
import matplotlib.pyplot as plt
convert_label = {' Myocardial infarction':0, ' Healthy control':1}


def wave_slicing_lstm(sig_data, window_size):
    slice_size = window_size
    data_length = sig_data.shape[0]
    sig_data = denoise(sig_data[0:data_length])
    #print('sig_data shape',sig_data.shape)
    #print('window_size',window_size)
    #print(sig_data)
    record_sliced = []
    try:
      n_windows = data_length//window_size -1 
      for i in range(n_windows): 
        tem_data = sig_data [i *slice_size : (i+1) *slice_size ]
        record_sliced.append(tem_data)
      #plot sample  
      #plt.plot(record_sliced[-1]) 
      #plt.show()

    except Exception as e:
      print('error:', e)

     #print(' record_sliced length:',len(record_sliced))   
    return record_sliced


def make_dataset_lstm(df_new, window_size):
  labels=[]
  record_sliced_list = []
  n_channels = len(df_new.data[0])
  for index in df_new.index:
    #print(index)
    label = df_new['label'][index]  

    signals_array = df_new['data'][index] 
    #print(signals_array.shape)
    is_first = True
    for i in range(len(signals_array)):
      sig_data = signals_array [i]
      #print(record.record_name+'_'+str(i)+' sig_data shape:', sig_data.shape)
      record_sliced = wave_slicing_lstm(sig_data, window_size)
      #print( record.record_name+'_'+str(i)+' record_sliced length:',len(record_sliced))
      for slice in record_sliced:
        record_sliced_list.append(slice)
        if is_first:   
          labels.append(label)
      is_first = False
  #print(len(record_sliced_list))
  record_sliced_list = np.array(record_sliced_list).reshape(-1, n_channels, window_size)
  labels = to_categorical(labels,2)
  return record_sliced_list, labels

X,y = make_dataset_lstm(df_new, window_size=1024)

#record0_sliced = wave_slicing_lstm(label_records[0].p_signal.T[0], window_size = 1000)

# %%
X.shape
# Out:
# (20608, 15, 1024)

# %%
y.shape
# Out:
# (20608, 2)

# %%
class TimeHistory(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.times = []

    def on_epoch_begin(self, batch, logs={}):
        self.epoch_time_start = time.time()

    def on_epoch_end(self, batch, logs={}):
        self.times.append(time.time() - self.epoch_time_start)

# %%
#split validated train and test set
trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.2, random_state=1)

#split validation set
testX, valX, testY, valY = train_test_split(testX, testY, test_size=0.25, random_state=1)

#Shuffle order of train set
trainX, trainY = shuffle(trainX, trainY)

#Since we have a large class inbalance we need to udjust the weights for it.
fractions = 1-trainY.sum(axis=0)/len(trainY)
weights = fractions[trainY.argmax(axis=1)]

# %%
trainX.shape
# Out:
# (16486, 15, 1024)

# %%
# %load_ext tensorboard
model_Path = '/gdrive/My Drive/model_output'

filepath = os.path.join(model_Path, "weights-improvement-{epoch:02d}-bigger.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

model_name = 'two_classes'
model_folder = os.path.join(model_Path,'tensorlogs/'+ model_name + "-logs/")

if not os.path.isdir(model_folder):
    n_logs = 0
else:
    n_logs = len(os.listdir(model_folder))
    
tensorboard_logs = os.path.join(model_folder, "%inth_run"%n_logs)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=tensorboard_logs, write_graph=False)
time_callback = TimeHistory()
callbacks = [checkpoint, tensorboard_callback, time_callback]

model = make_model_lstm((trainX.shape[1], trainX.shape[2]), trainY.shape[-1], LSTM)

model.fit(trainX, trainY, validation_data = (valX,valY), epochs=100, batch_size=256,sample_weight=weights, callbacks=callbacks)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# model dim:  (15, 1024) 2
# Epoch 1/100
# 65/65 [==============================] - 5s 32ms/step - loss: 0.3432 - binary_accuracy: 0.5629 - val_loss: 0.6711 - val_binary_accuracy: 0.5820
#
# Epoch 00001: loss improved from inf to 0.33799, saving model to /gdrive/My Drive/model_output/weights-improvement-01-bigger.hdf5
# Epoch 2/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3281 - binary_accuracy: 0.5994 - val_loss: 0.6402 - val_binary_accuracy: 0.6237
#
# Epoch 00002: loss improved from 0.33799 to 0.32478, saving model to /gdrive/My Drive/model_output/weights-improvement-02-bigger.hdf5
# Epoch 3/100
# 65/65 [==============================] - 1s 19ms/step - loss: 0.3157 - binary_accuracy: 0.6298 - val_loss: 0.6229 - val_binary_accuracy: 0.6479
#
# Epoch 00003: loss improved from 0.32478 to 0.31182, saving model to /gdrive/My Drive/model_output/weights-improvement-03-bigger.hdf5
# Epoch 4/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3001 - binary_accuracy: 0.6589 - val_loss: 0.5981 - val_binary_accuracy: 0.6819
#
# Epoch 00004: loss improved from 0.31182 to 0.29685, saving model to /gdrive/My Drive/model_output/weights-improvement-04-bigger.hdf5
# Epoch 5/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2772 - binary_accuracy: 0.6941 - val_loss: 0.5641 - val_binary_accuracy: 0.7003
#
# Epoch 00005: loss improved from 0.29685 to 0.27616, saving model to /gdrive/My Drive/model_output/weights-improvement-05-bigger.hdf5
# Epoch 6/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2585 - binary_accuracy: 0.7167 - val_loss: 0.5452 - val_binary_accuracy: 0.7168
#
# Epoch 00006: loss improved from 0.27616 to 0.25842, saving model to /gdrive/My Drive/model_output/weights-improvement-06-bigger.hdf5
# Epoch 7/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2372 - binary_accuracy: 0.7482 - val_loss: 0.5411 - val_binary_accuracy: 0.7042
#
# Epoch 00007: loss improved from 0.25842 to 0.23767, saving model to /gdrive/My Drive/model_output/weights-improvement-07-bigger.hdf5
# Epoch 8/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2245 - binary_accuracy: 0.7669 - val_loss: 0.5226 - val_binary_accuracy: 0.7527
#
# Epoch 00008: loss improved from 0.23767 to 0.22129, saving model to /gdrive/My Drive/model_output/weights-improvement-08-bigger.hdf5
# Epoch 9/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2082 - binary_accuracy: 0.7792 - val_loss: 0.5246 - val_binary_accuracy: 0.7488
#
# Epoch 00009: loss improved from 0.22129 to 0.20877, saving model to /gdrive/My Drive/model_output/weights-improvement-09-bigger.hdf5
# Epoch 10/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.1935 - binary_accuracy: 0.7963 - val_loss: 0.5380 - val_binary_accuracy: 0.7381
#
# Epoch 00010: loss improved from 0.20877 to 0.19301, saving model to /gdrive/My Drive/model_output/weights-improvement-10-bigger.hdf5
# Epoch 11/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1857 - binary_accuracy: 0.8087 - val_loss: 0.5201 - val_binary_accuracy: 0.7507
#
# Epoch 00011: loss improved from 0.19301 to 0.18363, saving model to /gdrive/My Drive/model_output/weights-improvement-11-bigger.hdf5
# Epoch 12/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1719 - binary_accuracy: 0.8236 - val_loss: 0.4774 - val_binary_accuracy: 0.7847
#
# Epoch 00012: loss improved from 0.18363 to 0.17070, saving model to /gdrive/My Drive/model_output/weights-improvement-12-bigger.hdf5
# Epoch 13/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1656 - binary_accuracy: 0.8269 - val_loss: 0.5152 - val_binary_accuracy: 0.7692
#
# Epoch 00013: loss improved from 0.17070 to 0.16458, saving model to /gdrive/My Drive/model_output/weights-improvement-13-bigger.hdf5
# Epoch 14/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1553 - binary_accuracy: 0.8425 - val_loss: 0.5955 - val_binary_accuracy: 0.7565
#
# Epoch 00014: loss improved from 0.16458 to 0.15462, saving model to /gdrive/My Drive/model_output/weights-improvement-14-bigger.hdf5
# Epoch 15/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1536 - binary_accuracy: 0.8409 - val_loss: 0.5427 - val_binary_accuracy: 0.7953
#
# Epoch 00015: loss improved from 0.15462 to 0.15089, saving model to /gdrive/My Drive/model_output/weights-improvement-15-bigger.hdf5
# Epoch 16/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1464 - binary_accuracy: 0.8523 - val_loss: 0.4963 - val_binary_accuracy: 0.8060
#
# Epoch 00016: loss improved from 0.15089 to 0.14479, saving model to /gdrive/My Drive/model_output/weights-improvement-16-bigger.hdf5
# Epoch 17/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1370 - binary_accuracy: 0.8595 - val_loss: 0.5047 - val_binary_accuracy: 0.7905
#
# Epoch 00017: loss improved from 0.14479 to 0.13762, saving model to /gdrive/My Drive/model_output/weights-improvement-17-bigger.hdf5
# Epoch 18/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1306 - binary_accuracy: 0.8644 - val_loss: 0.5317 - val_binary_accuracy: 0.8002
#
# Epoch 00018: loss improved from 0.13762 to 0.13014, saving model to /gdrive/My Drive/model_output/weights-improvement-18-bigger.hdf5
# Epoch 19/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1245 - binary_accuracy: 0.8740 - val_loss: 0.5552 - val_binary_accuracy: 0.7934
#
# Epoch 00019: loss improved from 0.13014 to 0.12244, saving model to /gdrive/My Drive/model_output/weights-improvement-19-bigger.hdf5
# Epoch 20/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1260 - binary_accuracy: 0.8754 - val_loss: 0.5474 - val_binary_accuracy: 0.8050
#
# Epoch 00020: loss did not improve from 0.12244
# Epoch 21/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1172 - binary_accuracy: 0.8819 - val_loss: 0.4863 - val_binary_accuracy: 0.8380
#
# Epoch 00021: loss improved from 0.12244 to 0.11482, saving model to /gdrive/My Drive/model_output/weights-improvement-21-bigger.hdf5
# Epoch 22/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1120 - binary_accuracy: 0.8887 - val_loss: 0.5025 - val_binary_accuracy: 0.8215
#
# Epoch 00022: loss improved from 0.11482 to 0.11422, saving model to /gdrive/My Drive/model_output/weights-improvement-22-bigger.hdf5
# Epoch 23/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1127 - binary_accuracy: 0.8881 - val_loss: 0.5090 - val_binary_accuracy: 0.8186
#
# Epoch 00023: loss improved from 0.11422 to 0.11340, saving model to /gdrive/My Drive/model_output/weights-improvement-23-bigger.hdf5
# Epoch 24/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1047 - binary_accuracy: 0.8967 - val_loss: 0.5416 - val_binary_accuracy: 0.8244
#
# Epoch 00024: loss improved from 0.11340 to 0.10788, saving model to /gdrive/My Drive/model_output/weights-improvement-24-bigger.hdf5
# Epoch 25/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.1064 - binary_accuracy: 0.8931 - val_loss: 0.5404 - val_binary_accuracy: 0.8235
#
# Epoch 00025: loss improved from 0.10788 to 0.10664, saving model to /gdrive/My Drive/model_output/weights-improvement-25-bigger.hdf5
# Epoch 26/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.1021 - binary_accuracy: 0.9020 - val_loss: 0.5246 - val_binary_accuracy: 0.8322
#
# Epoch 00026: loss improved from 0.10664 to 0.10324, saving model to /gdrive/My Drive/model_output/weights-improvement-26-bigger.hdf5
# Epoch 27/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0994 - binary_accuracy: 0.9007 - val_loss: 0.5726 - val_binary_accuracy: 0.8167
#
# Epoch 00027: loss improved from 0.10324 to 0.10260, saving model to /gdrive/My Drive/model_output/weights-improvement-27-bigger.hdf5
# Epoch 28/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0953 - binary_accuracy: 0.9065 - val_loss: 0.5491 - val_binary_accuracy: 0.8206
#
# Epoch 00028: loss improved from 0.10260 to 0.09908, saving model to /gdrive/My Drive/model_output/weights-improvement-28-bigger.hdf5
# Epoch 29/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.1006 - binary_accuracy: 0.8994 - val_loss: 0.5643 - val_binary_accuracy: 0.8380
#
# Epoch 00029: loss improved from 0.09908 to 0.09750, saving model to /gdrive/My Drive/model_output/weights-improvement-29-bigger.hdf5
# Epoch 30/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0975 - binary_accuracy: 0.9044 - val_loss: 0.4928 - val_binary_accuracy: 0.8332
#
# Epoch 00030: loss did not improve from 0.09750
# Epoch 31/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0909 - binary_accuracy: 0.9099 - val_loss: 0.4671 - val_binary_accuracy: 0.8390
#
# Epoch 00031: loss improved from 0.09750 to 0.09278, saving model to /gdrive/My Drive/model_output/weights-improvement-31-bigger.hdf5
# Epoch 32/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0910 - binary_accuracy: 0.9116 - val_loss: 0.5267 - val_binary_accuracy: 0.8312
#
# Epoch 00032: loss improved from 0.09278 to 0.09174, saving model to /gdrive/My Drive/model_output/weights-improvement-32-bigger.hdf5
# Epoch 33/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0940 - binary_accuracy: 0.9074 - val_loss: 0.5781 - val_binary_accuracy: 0.8322
#
# Epoch 00033: loss did not improve from 0.09174
# Epoch 34/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0873 - binary_accuracy: 0.9143 - val_loss: 0.5412 - val_binary_accuracy: 0.8341
#
# Epoch 00034: loss improved from 0.09174 to 0.09015, saving model to /gdrive/My Drive/model_output/weights-improvement-34-bigger.hdf5
# Epoch 35/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0863 - binary_accuracy: 0.9160 - val_loss: 0.5836 - val_binary_accuracy: 0.8293
#
# Epoch 00035: loss improved from 0.09015 to 0.08659, saving model to /gdrive/My Drive/model_output/weights-improvement-35-bigger.hdf5
# Epoch 36/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0861 - binary_accuracy: 0.9125 - val_loss: 0.4898 - val_binary_accuracy: 0.8487
#
# Epoch 00036: loss improved from 0.08659 to 0.08463, saving model to /gdrive/My Drive/model_output/weights-improvement-36-bigger.hdf5
# Epoch 37/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0818 - binary_accuracy: 0.9180 - val_loss: 0.5530 - val_binary_accuracy: 0.8332
#
# Epoch 00037: loss did not improve from 0.08463
# Epoch 38/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0828 - binary_accuracy: 0.9170 - val_loss: 0.5287 - val_binary_accuracy: 0.8438
#
# Epoch 00038: loss improved from 0.08463 to 0.08352, saving model to /gdrive/My Drive/model_output/weights-improvement-38-bigger.hdf5
# Epoch 39/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0826 - binary_accuracy: 0.9167 - val_loss: 0.6014 - val_binary_accuracy: 0.8206
#
# Epoch 00039: loss improved from 0.08352 to 0.08283, saving model to /gdrive/My Drive/model_output/weights-improvement-39-bigger.hdf5
# Epoch 40/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0944 - binary_accuracy: 0.9069 - val_loss: 0.4755 - val_binary_accuracy: 0.8477
#
# Epoch 00040: loss did not improve from 0.08283
# Epoch 41/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0835 - binary_accuracy: 0.9151 - val_loss: 0.4499 - val_binary_accuracy: 0.8594
#
# Epoch 00041: loss improved from 0.08283 to 0.08095, saving model to /gdrive/My Drive/model_output/weights-improvement-41-bigger.hdf5
# Epoch 42/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0763 - binary_accuracy: 0.9221 - val_loss: 0.5087 - val_binary_accuracy: 0.8477
#
# Epoch 00042: loss improved from 0.08095 to 0.07674, saving model to /gdrive/My Drive/model_output/weights-improvement-42-bigger.hdf5
# Epoch 43/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0799 - binary_accuracy: 0.9178 - val_loss: 0.4839 - val_binary_accuracy: 0.8535
#
# Epoch 00043: loss did not improve from 0.07674
# Epoch 44/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0761 - binary_accuracy: 0.9254 - val_loss: 0.5091 - val_binary_accuracy: 0.8555
#
# Epoch 00044: loss improved from 0.07674 to 0.07462, saving model to /gdrive/My Drive/model_output/weights-improvement-44-bigger.hdf5
# Epoch 45/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0733 - binary_accuracy: 0.9287 - val_loss: 0.4717 - val_binary_accuracy: 0.8642
#
# Epoch 00045: loss did not improve from 0.07462
# Epoch 46/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0728 - binary_accuracy: 0.9268 - val_loss: 0.4550 - val_binary_accuracy: 0.8458
#
# Epoch 00046: loss did not improve from 0.07462
# Epoch 47/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0774 - binary_accuracy: 0.9234 - val_loss: 0.4958 - val_binary_accuracy: 0.8584
#
# Epoch 00047: loss did not improve from 0.07462
# Epoch 48/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0714 - binary_accuracy: 0.9329 - val_loss: 0.5392 - val_binary_accuracy: 0.8574
#
# Epoch 00048: loss improved from 0.07462 to 0.07173, saving model to /gdrive/My Drive/model_output/weights-improvement-48-bigger.hdf5
# Epoch 49/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0752 - binary_accuracy: 0.9286 - val_loss: 0.4495 - val_binary_accuracy: 0.8613
#
# Epoch 00049: loss did not improve from 0.07173
# Epoch 50/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0713 - binary_accuracy: 0.9299 - val_loss: 0.4842 - val_binary_accuracy: 0.8574
#
# Epoch 00050: loss did not improve from 0.07173
# Epoch 51/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0689 - binary_accuracy: 0.9328 - val_loss: 0.4456 - val_binary_accuracy: 0.8720
#
# Epoch 00051: loss improved from 0.07173 to 0.06987, saving model to /gdrive/My Drive/model_output/weights-improvement-51-bigger.hdf5
# Epoch 52/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0728 - binary_accuracy: 0.9283 - val_loss: 0.5129 - val_binary_accuracy: 0.8477
#
# Epoch 00052: loss did not improve from 0.06987
# Epoch 53/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0784 - binary_accuracy: 0.9246 - val_loss: 0.5255 - val_binary_accuracy: 0.8419
#
# Epoch 00053: loss did not improve from 0.06987
# Epoch 54/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0670 - binary_accuracy: 0.9334 - val_loss: 0.5339 - val_binary_accuracy: 0.8526
#
# Epoch 00054: loss improved from 0.06987 to 0.06814, saving model to /gdrive/My Drive/model_output/weights-improvement-54-bigger.hdf5
# Epoch 55/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0676 - binary_accuracy: 0.9336 - val_loss: 0.4780 - val_binary_accuracy: 0.8671
#
# Epoch 00055: loss improved from 0.06814 to 0.06778, saving model to /gdrive/My Drive/model_output/weights-improvement-55-bigger.hdf5
# Epoch 56/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0661 - binary_accuracy: 0.9350 - val_loss: 0.4994 - val_binary_accuracy: 0.8720
#
# Epoch 00056: loss improved from 0.06778 to 0.06518, saving model to /gdrive/My Drive/model_output/weights-improvement-56-bigger.hdf5
# Epoch 57/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0660 - binary_accuracy: 0.9331 - val_loss: 0.4899 - val_binary_accuracy: 0.8700
#
# Epoch 00057: loss did not improve from 0.06518
# Epoch 58/100
# 65/65 [==============================] - 1s 19ms/step - loss: 0.0716 - binary_accuracy: 0.9293 - val_loss: 0.5271 - val_binary_accuracy: 0.8458
#
# Epoch 00058: loss did not improve from 0.06518
# Epoch 59/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0683 - binary_accuracy: 0.9329 - val_loss: 0.5287 - val_binary_accuracy: 0.8623
#
# Epoch 00059: loss did not improve from 0.06518
# Epoch 60/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0696 - binary_accuracy: 0.9332 - val_loss: 0.5438 - val_binary_accuracy: 0.8487
#
# Epoch 00060: loss did not improve from 0.06518
# Epoch 61/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0710 - binary_accuracy: 0.9306 - val_loss: 0.5649 - val_binary_accuracy: 0.8477
#
# Epoch 00061: loss did not improve from 0.06518
# Epoch 62/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0646 - binary_accuracy: 0.9367 - val_loss: 0.6152 - val_binary_accuracy: 0.8535
#
# Epoch 00062: loss improved from 0.06518 to 0.06381, saving model to /gdrive/My Drive/model_output/weights-improvement-62-bigger.hdf5
# Epoch 63/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0657 - binary_accuracy: 0.9371 - val_loss: 0.5190 - val_binary_accuracy: 0.8594
#
# Epoch 00063: loss did not improve from 0.06381
# Epoch 64/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0661 - binary_accuracy: 0.9377 - val_loss: 0.5181 - val_binary_accuracy: 0.8671
#
# Epoch 00064: loss did not improve from 0.06381
# Epoch 65/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0636 - binary_accuracy: 0.9381 - val_loss: 0.4778 - val_binary_accuracy: 0.8545
#
# Epoch 00065: loss did not improve from 0.06381
# Epoch 66/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0635 - binary_accuracy: 0.9373 - val_loss: 0.5505 - val_binary_accuracy: 0.8613
#
# Epoch 00066: loss improved from 0.06381 to 0.06331, saving model to /gdrive/My Drive/model_output/weights-improvement-66-bigger.hdf5
# Epoch 67/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0609 - binary_accuracy: 0.9373 - val_loss: 0.6295 - val_binary_accuracy: 0.8371
#
# Epoch 00067: loss improved from 0.06331 to 0.06151, saving model to /gdrive/My Drive/model_output/weights-improvement-67-bigger.hdf5
# Epoch 68/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0637 - binary_accuracy: 0.9366 - val_loss: 0.5967 - val_binary_accuracy: 0.8438
#
# Epoch 00068: loss did not improve from 0.06151
# Epoch 69/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0652 - binary_accuracy: 0.9376 - val_loss: 0.5416 - val_binary_accuracy: 0.8506
#
# Epoch 00069: loss did not improve from 0.06151
# Epoch 70/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0639 - binary_accuracy: 0.9400 - val_loss: 0.5032 - val_binary_accuracy: 0.8681
#
# Epoch 00070: loss did not improve from 0.06151
# Epoch 71/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0664 - binary_accuracy: 0.9341 - val_loss: 0.5152 - val_binary_accuracy: 0.8477
#
# Epoch 00071: loss did not improve from 0.06151
# Epoch 72/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0589 - binary_accuracy: 0.9434 - val_loss: 0.5552 - val_binary_accuracy: 0.8739
#
# Epoch 00072: loss improved from 0.06151 to 0.05790, saving model to /gdrive/My Drive/model_output/weights-improvement-72-bigger.hdf5
# Epoch 73/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0590 - binary_accuracy: 0.9422 - val_loss: 0.5553 - val_binary_accuracy: 0.8477
#
# Epoch 00073: loss did not improve from 0.05790
# Epoch 74/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0584 - binary_accuracy: 0.9424 - val_loss: 0.5664 - val_binary_accuracy: 0.8603
#
# Epoch 00074: loss improved from 0.05790 to 0.05771, saving model to /gdrive/My Drive/model_output/weights-improvement-74-bigger.hdf5
# Epoch 75/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0595 - binary_accuracy: 0.9456 - val_loss: 0.5704 - val_binary_accuracy: 0.8419
#
# Epoch 00075: loss did not improve from 0.05771
# Epoch 76/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0562 - binary_accuracy: 0.9451 - val_loss: 0.5809 - val_binary_accuracy: 0.8468
#
# Epoch 00076: loss improved from 0.05771 to 0.05618, saving model to /gdrive/My Drive/model_output/weights-improvement-76-bigger.hdf5
# Epoch 77/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0570 - binary_accuracy: 0.9444 - val_loss: 0.5787 - val_binary_accuracy: 0.8652
#
# Epoch 00077: loss improved from 0.05618 to 0.05564, saving model to /gdrive/My Drive/model_output/weights-improvement-77-bigger.hdf5
# Epoch 78/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0563 - binary_accuracy: 0.9473 - val_loss: 0.5686 - val_binary_accuracy: 0.8584
#
# Epoch 00078: loss did not improve from 0.05564
# Epoch 79/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0560 - binary_accuracy: 0.9475 - val_loss: 0.5935 - val_binary_accuracy: 0.8506
#
# Epoch 00079: loss did not improve from 0.05564
# Epoch 80/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0555 - binary_accuracy: 0.9464 - val_loss: 0.5135 - val_binary_accuracy: 0.8603
#
# Epoch 00080: loss did not improve from 0.05564
# Epoch 81/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0545 - binary_accuracy: 0.9493 - val_loss: 0.5811 - val_binary_accuracy: 0.8487
#
# Epoch 00081: loss did not improve from 0.05564
# Epoch 82/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0573 - binary_accuracy: 0.9474 - val_loss: 0.5004 - val_binary_accuracy: 0.8574
#
# Epoch 00082: loss did not improve from 0.05564
# Epoch 83/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0569 - binary_accuracy: 0.9432 - val_loss: 0.5325 - val_binary_accuracy: 0.8535
#
# Epoch 00083: loss did not improve from 0.05564
# Epoch 84/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0641 - binary_accuracy: 0.9404 - val_loss: 0.5413 - val_binary_accuracy: 0.8603
#
# Epoch 00084: loss did not improve from 0.05564
# Epoch 85/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0563 - binary_accuracy: 0.9452 - val_loss: 0.6021 - val_binary_accuracy: 0.8661
#
# Epoch 00085: loss improved from 0.05564 to 0.05423, saving model to /gdrive/My Drive/model_output/weights-improvement-85-bigger.hdf5
# Epoch 86/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0496 - binary_accuracy: 0.9534 - val_loss: 0.5188 - val_binary_accuracy: 0.8826
#
# Epoch 00086: loss improved from 0.05423 to 0.05163, saving model to /gdrive/My Drive/model_output/weights-improvement-86-bigger.hdf5
# Epoch 87/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0561 - binary_accuracy: 0.9444 - val_loss: 0.6296 - val_binary_accuracy: 0.8506
#
# Epoch 00087: loss did not improve from 0.05163
# Epoch 88/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0551 - binary_accuracy: 0.9481 - val_loss: 0.5580 - val_binary_accuracy: 0.8652
#
# Epoch 00088: loss did not improve from 0.05163
# Epoch 89/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0518 - binary_accuracy: 0.9507 - val_loss: 0.5570 - val_binary_accuracy: 0.8584
#
# Epoch 00089: loss did not improve from 0.05163
# Epoch 90/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0482 - binary_accuracy: 0.9528 - val_loss: 0.5701 - val_binary_accuracy: 0.8652
#
# Epoch 00090: loss improved from 0.05163 to 0.05011, saving model to /gdrive/My Drive/model_output/weights-improvement-90-bigger.hdf5
# Epoch 91/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0537 - binary_accuracy: 0.9482 - val_loss: 0.5371 - val_binary_accuracy: 0.8758
#
# Epoch 00091: loss did not improve from 0.05011
# Epoch 92/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0492 - binary_accuracy: 0.9520 - val_loss: 0.6051 - val_binary_accuracy: 0.8768
#
# Epoch 00092: loss improved from 0.05011 to 0.04809, saving model to /gdrive/My Drive/model_output/weights-improvement-92-bigger.hdf5
# Epoch 93/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0469 - binary_accuracy: 0.9543 - val_loss: 0.6060 - val_binary_accuracy: 0.8623
#
# Epoch 00093: loss did not improve from 0.04809
# Epoch 94/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0521 - binary_accuracy: 0.9530 - val_loss: 0.5200 - val_binary_accuracy: 0.8691
#
# Epoch 00094: loss did not improve from 0.04809
# Epoch 95/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0514 - binary_accuracy: 0.9502 - val_loss: 0.5346 - val_binary_accuracy: 0.8671
#
# Epoch 00095: loss did not improve from 0.04809
# Epoch 96/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0550 - binary_accuracy: 0.9491 - val_loss: 0.5419 - val_binary_accuracy: 0.8739
#
# Epoch 00096: loss did not improve from 0.04809
# Epoch 97/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0503 - binary_accuracy: 0.9521 - val_loss: 0.7032 - val_binary_accuracy: 0.8574
#
# Epoch 00097: loss did not improve from 0.04809
# Epoch 98/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.0520 - binary_accuracy: 0.9521 - val_loss: 0.6104 - val_binary_accuracy: 0.8497
#
# Epoch 00098: loss did not improve from 0.04809
# Epoch 99/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0490 - binary_accuracy: 0.9546 - val_loss: 0.5305 - val_binary_accuracy: 0.8700
#
# Epoch 00099: loss did not improve from 0.04809
# Epoch 100/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.0506 - binary_accuracy: 0.9515 - val_loss: 0.5376 - val_binary_accuracy: 0.8768
#
# Epoch 00100: loss did not improve from 0.04809

# %%
output = model.predict(testX)
output_ = np.argmax(output,axis=1)
y_pred = output_
y_true = testY.argmax(axis=1)
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, labels=[0,1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86      1519
#            1       0.87      0.87      0.87      1572
#
#     accuracy                           0.87      3091
#    macro avg       0.87      0.87      0.87      3091
# weighted avg       0.87      0.87      0.87      3091

# %% [markdown]
# #CNN+LSTM

# %%
import keras
from scipy.io import loadmat
import matplotlib.pyplot as plt
import glob
import numpy as np
import pandas as pd
import math
import os
from keras.layers import *
from keras.models import *
from keras.objectives import *

time_step = 1024
num_sensors = 15
num_classes = 2
Batch_size = 32
num_epoch = 300

def conv_block_type1(x,num_filters, kernel_size):
    x = Conv1D(num_filters, kernel_size, activation='relu', padding="same")(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Conv1D(num_filters, kernel_size, activation='relu', padding="same")(x)
    x = MaxPooling1D()(x)

    return x


def conv_block_type2(x,num_filters, kernel_size):
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Conv1D(num_filters, kernel_size, activation='relu', padding="same")(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.5)(x)
    x = Conv1D(num_filters, kernel_size, activation='relu', padding="same")(x)
    x = MaxPooling1D()(x)

    return x


def build_model(time_step,num_sensors, num_classes):
    input_shape = (time_step,num_sensors)

    #CNNModel
    inpt = keras.layers.Input(input_shape)

    x = Conv1D(32, 16, activation='relu')(inpt)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = conv_block_type1(x, 32, 16)

    x = conv_block_type2(x, 32, 16)
    x = conv_block_type2(x, 64, 8)
    x = conv_block_type2(x, 64, 8)
    x = conv_block_type2(x, 128, 4)
    x = conv_block_type2(x, 128, 4)

    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Bidirectional(LSTM(64, return_sequences=True, input_shape=(None, 1)))(x)
    x = GlobalMaxPooling1D()(x)

    x = Dense(32, activation='relu', input_shape=(None, 128))(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = keras.Model(inputs=inpt, outputs=x)

    return(model)

# %%
model_test3 = build_model(time_step,num_sensors,2)
model_test3.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1024, 15)]        0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 1009, 32)          7712
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1009, 32)          128
# _________________________________________________________________
# re_lu (ReLU)                 (None, 1009, 32)          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 1009, 32)          16416
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1009, 32)          128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 1009, 32)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1009, 32)          0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 1009, 32)          16416
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 504, 32)           0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 504, 32)           128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 504, 32)           0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 504, 32)           0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 504, 32)           16416
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 504, 32)           128
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 504, 32)           0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 504, 32)           0
# _________________________________________________________________
# conv1d_8 (Conv1D)            (None, 504, 32)           16416
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 252, 32)           0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 252, 32)           128
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 252, 32)           0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 252, 32)           0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 252, 64)           16448
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 252, 64)           256
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 252, 64)           0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 252, 64)           0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 252, 64)           32832
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 126, 64)           0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 126, 64)           256
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 126, 64)           0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 126, 64)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 126, 64)           32832
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 126, 64)           256
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 126, 64)           0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 126, 64)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 126, 64)           32832
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 63, 64)            0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 63, 64)            256
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 63, 64)            0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 63, 64)            0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 63, 128)           32896
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 63, 128)           512
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 63, 128)           0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 63, 128)           0
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 63, 128)           65664
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 31, 128)           0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 31, 128)           512
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 31, 128)           0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 31, 128)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 31, 128)           65664
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 31, 128)           512
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 31, 128)           0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 31, 128)           0
# _________________________________________________________________
# conv1d_16 (Conv1D)           (None, 31, 128)           65664
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 15, 128)           0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 15, 128)           512
# _________________________________________________________________
# re_lu_12 (ReLU)              (None, 15, 128)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 15, 128)           98816
# _________________________________________________________________
# global_max_pooling1d (Global (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 524,930
# Trainable params: 523,074
# Non-trainable params: 1,856
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model_test3, to_file='/content/gdrive/My Drive/physionet.org/model3_plot.png', show_shapes=True, show_layer_names=True)

# %%
 # %load_ext tensorboard
model_Path = '/gdrive/My Drive/model_output'

filepath = os.path.join(model_Path, "weights-improvement-{epoch:02d}-bigger.hdf5")
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')

model_name = 'two_classes'
model_folder = os.path.join(model_Path,'tensorlogs/'+ model_name + "-logs/")

if not os.path.isdir(model_folder):
    n_logs = 0
else:
    n_logs = len(os.listdir(model_folder))
    
tensorboard_logs = os.path.join(model_folder, "%inth_run"%n_logs)
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=tensorboard_logs, write_graph=False)
time_callback = TimeHistory()
callbacks = [checkpoint, tensorboard_callback]
model_test3.compile(optimizer = 'adam' , 
                  loss = "binary_crossentropy", metrics=["binary_accuracy"])
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
def reshape_for_CNN_plus_LSTM(data):
  return data.transpose((0,2,1))

# %%
trainX = reshape_for_CNN_plus_LSTM(trainX)
valX = reshape_for_CNN_plus_LSTM(valX)
testX = reshape_for_CNN_plus_LSTM(testX)

# %%
valX.shape
# Out:
# (1031, 1024, 15)

# %%
model_test3.fit(trainX, trainY,validation_data=(valX, valY), epochs=150, 
                batch_size=256,sample_weight=weights, callbacks=callbacks)
# Out:
# Epoch 1/150
# 65/65 [==============================] - 5s 80ms/step - loss: 0.2723 - binary_accuracy: 0.7119 - val_loss: 0.6526 - val_binary_accuracy: 0.5810
#
# Epoch 00001: loss improved from 0.27390 to 0.27232, saving model to /gdrive/My Drive/model_output/weights-improvement-01-bigger.hdf5
# Epoch 2/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2739 - binary_accuracy: 0.7006 - val_loss: 0.6353 - val_binary_accuracy: 0.6101
#
# Epoch 00002: loss did not improve from 0.27232
# Epoch 3/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2728 - binary_accuracy: 0.7059 - val_loss: 0.6338 - val_binary_accuracy: 0.6101
#
# Epoch 00003: loss did not improve from 0.27232
# Epoch 4/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2733 - binary_accuracy: 0.7041 - val_loss: 0.6396 - val_binary_accuracy: 0.6052
#
# Epoch 00004: loss did not improve from 0.27232
# Epoch 5/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2727 - binary_accuracy: 0.7130 - val_loss: 0.6547 - val_binary_accuracy: 0.5820
#
# Epoch 00005: loss did not improve from 0.27232
# Epoch 6/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2713 - binary_accuracy: 0.7093 - val_loss: 0.6419 - val_binary_accuracy: 0.6120
#
# Epoch 00006: loss improved from 0.27232 to 0.27130, saving model to /gdrive/My Drive/model_output/weights-improvement-06-bigger.hdf5
# Epoch 7/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2714 - binary_accuracy: 0.7119 - val_loss: 0.6508 - val_binary_accuracy: 0.5781
#
# Epoch 00007: loss did not improve from 0.27130
# Epoch 8/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2719 - binary_accuracy: 0.7119 - val_loss: 0.6553 - val_binary_accuracy: 0.5781
#
# Epoch 00008: loss did not improve from 0.27130
# Epoch 9/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2723 - binary_accuracy: 0.7097 - val_loss: 0.6513 - val_binary_accuracy: 0.5965
#
# Epoch 00009: loss did not improve from 0.27130
# Epoch 10/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2700 - binary_accuracy: 0.7164 - val_loss: 0.6459 - val_binary_accuracy: 0.5829
#
# Epoch 00010: loss improved from 0.27130 to 0.26996, saving model to /gdrive/My Drive/model_output/weights-improvement-10-bigger.hdf5
# Epoch 11/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2680 - binary_accuracy: 0.7164 - val_loss: 0.6623 - val_binary_accuracy: 0.5868
#
# Epoch 00011: loss improved from 0.26996 to 0.26799, saving model to /gdrive/My Drive/model_output/weights-improvement-11-bigger.hdf5
# Epoch 12/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2688 - binary_accuracy: 0.7142 - val_loss: 0.6449 - val_binary_accuracy: 0.5946
#
# Epoch 00012: loss did not improve from 0.26799
# Epoch 13/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2671 - binary_accuracy: 0.7171 - val_loss: 0.6484 - val_binary_accuracy: 0.5936
#
# Epoch 00013: loss improved from 0.26799 to 0.26714, saving model to /gdrive/My Drive/model_output/weights-improvement-13-bigger.hdf5
# Epoch 14/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2671 - binary_accuracy: 0.7162 - val_loss: 0.6414 - val_binary_accuracy: 0.5917
#
# Epoch 00014: loss improved from 0.26714 to 0.26706, saving model to /gdrive/My Drive/model_output/weights-improvement-14-bigger.hdf5
# Epoch 15/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2667 - binary_accuracy: 0.7156 - val_loss: 0.6415 - val_binary_accuracy: 0.5917
#
# Epoch 00015: loss improved from 0.26706 to 0.26668, saving model to /gdrive/My Drive/model_output/weights-improvement-15-bigger.hdf5
# Epoch 16/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2671 - binary_accuracy: 0.7212 - val_loss: 0.6420 - val_binary_accuracy: 0.5994
#
# Epoch 00016: loss did not improve from 0.26668
# Epoch 17/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2670 - binary_accuracy: 0.7247 - val_loss: 0.6589 - val_binary_accuracy: 0.5849
#
# Epoch 00017: loss did not improve from 0.26668
# Epoch 18/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2651 - binary_accuracy: 0.7192 - val_loss: 0.6401 - val_binary_accuracy: 0.5955
#
# Epoch 00018: loss improved from 0.26668 to 0.26508, saving model to /gdrive/My Drive/model_output/weights-improvement-18-bigger.hdf5
# Epoch 19/150
# 65/65 [==============================] - 5s 74ms/step - loss: 0.2682 - binary_accuracy: 0.7181 - val_loss: 0.6339 - val_binary_accuracy: 0.6159
#
# Epoch 00019: loss did not improve from 0.26508
# Epoch 20/150

# %%
output = model_test3.predict(testX)
output_ = np.argmax(output,axis=1)
y_pred = output_
y_true = testY.argmax(axis=1)
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, labels=[0,1]))
